# %%
import pandas as pd

# %%
def_df = pd.read_csv('Data/def_df.csv')
play_df = pd.read_csv('Data/play_df.csv')

# %%
def_df
# Out:
#    Def_Tm  Def_Year  Def_PF  Def_Fum_Play  Def_Att_Pass  Def_Comp_Pct  \
# 0     MIN      2017     252      0.005230           555      0.583784
# 1     JAX      2017     268      0.012085           509      0.567780
# 2     LAC      2017     272      0.009027           524      0.627863
# 3     PHI      2017     295      0.012295           601      0.603993
# 4      NE      2017     296      0.005871           590      0.622034
# ..    ...       ...     ...           ...           ...           ...
# 91    ARI      2019     442      0.009259           601      0.700499
# 92     TB      2019     449      0.014911           664      0.614458
# 93    NYG      2019     451      0.005655           556      0.663669
# 94    CAR      2019     470      0.006718           544      0.637868
# 95    MIA      2019     494      0.002849           545      0.631193
#
#     Def_TD_PA  Def_INT_PA  Def_NY/A  Def_1D_PA  Def_Att_Rush  Def_TD_RA  \
# ...

# %%
play_df
# Out:
#        Year posteam defteam  posteam_type  yardline_100  \
# 0      2019     ATL     MIN             0          75.0
# 1      2019     ATL     MIN             0          83.0
# 2      2019     ATL     MIN             0          79.0
# 3      2019     MIN     ATL             1          31.0
# 4      2019     MIN     ATL             1          23.0
# ...     ...     ...     ...           ...           ...
# 99968  2018      NE     PHI             1          91.0
# 99969  2018      NE     PHI             1          78.0
# 99970  2018      NE     PHI             1          67.0
# 99971  2018      NE     PHI             1          51.0
# 99972  2018      NE     PHI             1          51.0
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# 0                          900.0                  1800.0
# 1                          860.0                  1760.0
# 2                          821.0                  1721.0
# 3                          752.0                  1652.0
# ...

# %%
final_df = pd.merge(play_df, def_df,  how='left', left_on=['Year','defteam'], right_on = ['Def_Year','Def_Tm'])

# %%
final_df
# Out:
#        Year posteam defteam  posteam_type  yardline_100  \
# 0      2019     ATL     MIN             0          75.0
# 1      2019     ATL     MIN             0          83.0
# 2      2019     ATL     MIN             0          79.0
# 3      2019     MIN     ATL             1          31.0
# 4      2019     MIN     ATL             1          23.0
# ...     ...     ...     ...           ...           ...
# 99968  2018      NE     PHI             1          91.0
# 99969  2018      NE     PHI             1          78.0
# 99970  2018      NE     PHI             1          67.0
# 99971  2018      NE     PHI             1          51.0
# 99972  2018      NE     PHI             1          51.0
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# 0                          900.0                  1800.0
# 1                          860.0                  1760.0
# 2                          821.0                  1721.0
# 3                          752.0                  1652.0
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99973 entries, 0 to 99972
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       99973 non-null  int64
#  1   posteam                    99973 non-null  object
#  2   defteam                    99973 non-null  object
#  3   posteam_type               99973 non-null  int64
#  4   yardline_100               99973 non-null  float64
#  5   quarter_seconds_remaining  99973 non-null  float64
#  6   half_seconds_remaining     99973 non-null  float64
#  7   game_seconds_remaining     99973 non-null  float64
#  8   qtr                        99973 non-null  int64
#  9   down                       99973 non-null  float64
#  10  goal_to_go                 99973 non-null  int64
#  11  ydstogo                    99973 non-null  int64
#  12  play_type                  99973 non-null  object
# ...

# %%
final_df = final_df.drop(columns={'Def_Tm', 'Def_Year'})
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99973 entries, 0 to 99972
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       99973 non-null  int64
#  1   posteam                    99973 non-null  object
#  2   defteam                    99973 non-null  object
#  3   posteam_type               99973 non-null  int64
#  4   yardline_100               99973 non-null  float64
#  5   quarter_seconds_remaining  99973 non-null  float64
#  6   half_seconds_remaining     99973 non-null  float64
#  7   game_seconds_remaining     99973 non-null  float64
#  8   qtr                        99973 non-null  int64
#  9   down                       99973 non-null  float64
#  10  goal_to_go                 99973 non-null  int64
#  11  ydstogo                    99973 non-null  int64
#  12  play_type                  99973 non-null  object
# ...

# %%
final_df.to_csv(r'C:\Users\Garth Torok\MattTorok\capstone\merged_df.csv', index=False)
