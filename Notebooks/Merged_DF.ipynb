# %% [markdown]
# # Merging Into a Final DF

# %% [markdown]
# Now that we have created our 3 seperate dataframes, we will import them and merge them into a single dataframe to model off of.

# %%
# Import Library
import pandas as pd

# %%
# Import previously created .csv files
def_df = pd.read_csv('Data/def_df.csv')
play_df = pd.read_csv('Data/play_df.csv')
off_df = pd.read_csv('Data/off_df.csv')

# %%
def_df
# Out:
#    Def_Tm  Def_Year  Def_PF  Def_Fum_Play  Def_Comp_Pct  Def_TD_PA  \
# 0     MIN      2017     252      0.005230      0.583784   0.023423
# 1     JAX      2017     268      0.012085      0.567780   0.033399
# 2     LAC      2017     272      0.009027      0.627863   0.032443
# 3     PHI      2017     295      0.012295      0.603993   0.039933
# 4      NE      2017     296      0.005871      0.622034   0.040678
# ..    ...       ...     ...           ...           ...        ...
# 91    ARI      2019     442      0.009259      0.700499   0.063228
# 92     TB      2019     449      0.014911      0.614458   0.045181
# 93    NYG      2019     451      0.005655      0.663669   0.053957
# 94    CAR      2019     470      0.006718      0.637868   0.038603
# 95    MIA      2019     494      0.002849      0.631193   0.071560
#
#     Def_INT_PA  Def_NY/A  Def_1D_PA  Def_TD_RA  Def_Y/A  Def_1D_RA  \
# 0     0.025225       5.2   0.302703   0.027473      3.7   0.162088
# ...

# %%
play_df
# Out:
#        Year posteam defteam  posteam_type  yardline_100  \
# 0      2019     ATL     MIN             0          75.0
# 1      2019     ATL     MIN             0          83.0
# 2      2019     ATL     MIN             0          79.0
# 3      2019     MIN     ATL             1          31.0
# 4      2019     MIN     ATL             1          23.0
# ...     ...     ...     ...           ...           ...
# 99968  2018      NE     PHI             1          91.0
# 99969  2018      NE     PHI             1          78.0
# 99970  2018      NE     PHI             1          67.0
# 99971  2018      NE     PHI             1          51.0
# 99972  2018      NE     PHI             1          51.0
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# 0                          900.0                  1800.0
# 1                          860.0                  1760.0
# 2                          821.0                  1721.0
# 3                          752.0                  1652.0
# ...

# %%
off_df
# Out:
#    Off_Tm  Off_Year  Off_PF  Off_Fum_Play  Off_Comp_Pct  Off_TD_PA  \
# 0      LA      2017   478.0      0.014000      0.617761   0.054054
# 1      NE      2017   458.0      0.003738      0.662692   0.054514
# 2     PHI      2017   457.0      0.010252      0.604610   0.067376
# 3      NO      2017   448.0      0.010000      0.720149   0.042910
# 4     JAX      2017   417.0      0.009276      0.599620   0.039848
# ..    ...       ...     ...           ...           ...        ...
# 91    DEN      2019   282.0      0.006289      0.619048   0.031746
# 92    CHI      2019   280.0      0.006863      0.639655   0.034483
# 93    CIN      2019   279.0      0.013346      0.577922   0.029221
# 94    NYJ      2019   276.0      0.009414      0.619962   0.036468
# 95    WAS      2019   266.0      0.009040      0.622129   0.037578
#
#     Off_INT_PA  Off_NY/A  Off_1D_PA  Off_TD_RA  Off_Y/A  Off_1D_RA  \
# 0     0.013514       7.0   0.357143   0.037445      4.3   0.213656
# ...

# %% [markdown]
# We will merge our dataframes in two steps using left joins merged on both the year and team names:
#
# * First we will merge the play_df with our off_df
# * Second we will merge the above merged df with our def_df

# %%
# Merge all dfs
final_df = pd.merge(play_df, off_df,  how='left', left_on=['Year','posteam'], right_on = ['Off_Year','Off_Tm'])
final_df = pd.merge(final_df, def_df,  how='left', left_on=['Year','defteam'], right_on = ['Def_Year','Def_Tm'])

# %%
final_df
# Out:
#        Year posteam defteam  posteam_type  yardline_100  \
# 0      2019     ATL     MIN             0          75.0
# 1      2019     ATL     MIN             0          83.0
# 2      2019     ATL     MIN             0          79.0
# 3      2019     MIN     ATL             1          31.0
# 4      2019     MIN     ATL             1          23.0
# ...     ...     ...     ...           ...           ...
# 99968  2018      NE     PHI             1          91.0
# 99969  2018      NE     PHI             1          78.0
# 99970  2018      NE     PHI             1          67.0
# 99971  2018      NE     PHI             1          51.0
# 99972  2018      NE     PHI             1          51.0
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# 0                          900.0                  1800.0
# 1                          860.0                  1760.0
# 2                          821.0                  1721.0
# 3                          752.0                  1652.0
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99973 entries, 0 to 99972
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       99973 non-null  int64
#  1   posteam                    99973 non-null  object
#  2   defteam                    99973 non-null  object
#  3   posteam_type               99973 non-null  int64
#  4   yardline_100               99973 non-null  float64
#  5   quarter_seconds_remaining  99973 non-null  float64
#  6   half_seconds_remaining     99973 non-null  float64
#  7   game_seconds_remaining     99973 non-null  float64
#  8   qtr                        99973 non-null  int64
#  9   down                       99973 non-null  float64
#  10  goal_to_go                 99973 non-null  int64
#  11  ydstogo                    99973 non-null  int64
#  12  play_type                  99973 non-null  object
# ...

# %% [markdown]
# Now we can drop the team name and year columns from the dataframe as they were already displayed from our original play_df.

# %%
# Drop redundant columns
final_df = final_df.drop(columns={'Off_Tm', 'Off_Year', 'Def_Tm', 'Def_Year'})
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99973 entries, 0 to 99972
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       99973 non-null  int64
#  1   posteam                    99973 non-null  object
#  2   defteam                    99973 non-null  object
#  3   posteam_type               99973 non-null  int64
#  4   yardline_100               99973 non-null  float64
#  5   quarter_seconds_remaining  99973 non-null  float64
#  6   half_seconds_remaining     99973 non-null  float64
#  7   game_seconds_remaining     99973 non-null  float64
#  8   qtr                        99973 non-null  int64
#  9   down                       99973 non-null  float64
#  10  goal_to_go                 99973 non-null  int64
#  11  ydstogo                    99973 non-null  int64
#  12  play_type                  99973 non-null  object
# ...

# %%
# Save DF to csv file
final_df.to_csv(r'C:\Users\Garth Torok\MattTorok\capstone\Data\merged_df.csv', index=False)
